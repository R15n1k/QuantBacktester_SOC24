# %%
from data_fetch import download_historical_data
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
symbol="BTC-USD"
start_date="2024-06-01"
end_date="2024-06-18"
timeframe="1d"

# %%
df=download_historical_data(symbol,start_date,end_date,timeframe)
# print(df)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df
# Out:
#          Date          Open          High           Low         Close  \
# 0  2024-06-01  67489.609375  67839.765625  67386.195312  67706.937500
# 1  2024-06-02  67710.273438  68409.164062  67315.523438  67751.601562
# 2  2024-06-03  67753.898438  70230.820312  67589.835938  68804.781250
# 3  2024-06-04  68804.570312  71047.406250  68564.640625  70567.765625
# 4  2024-06-05  70568.351562  71735.414062  70390.710938  71082.820312
# 5  2024-06-06  71082.843750  71625.734375  70119.125000  70757.164062
# 6  2024-06-07  70759.187500  71907.851562  68507.257812  69342.585938
# 7  2024-06-08  69324.179688  69533.320312  69210.742188  69305.773438
# 8  2024-06-09  69297.492188  69817.523438  69160.843750  69647.992188
# 9  2024-06-10  69644.312500  70146.070312  69232.421875  69512.281250
# 10 2024-06-11  69508.078125  69549.414062  66123.601562  67332.031250
# 11 2024-06-12  67321.375000  69977.890625  66902.453125  68241.187500
# 12 2024-06-13  68243.101562  68365.781250  66304.562500  66756.398438
# 13 2024-06-14  66747.570312  67294.648438  65056.894531  66011.093750
# 14 2024-06-15  66006.742188  66402.187500  65871.773438  66191.000000
# 15 2024-06-16  66189.359375  66894.843750  66018.250000  66639.046875
# 16 2024-06-17  66636.515625  67188.320312  65094.964844  66490.296875
#
#        Adj Close       Volume
# 0   67706.937500  11641495604
# 1   67751.601562  17110588415
# 2   68804.781250  32401285324
# 3   70567.765625  33149696545
# 4   71082.820312  32810771409
# 5   70757.164062  25223152007
# 6   69342.585938  36188381096
# 7   69305.773438  14262185861
# 8   69647.992188  13534028500
# 9   69512.281250  20597699541
# 10  67332.031250  37116136345
# 11  68241.187500  34497940694
# 12  66756.398438  28955204146
# 13  66011.093750  27403884779
# 14  66191.000000  14121265576
# 15  66639.046875  13281140541
# 16  66490.296875  30006354476

# %%
# For plotting the graph
plt.figure(figsize=(10,6))

plt.plot(df["Date"],df["Close"],marker="o")

plt.xlabel("Dates",fontsize=16)
plt.ylabel("Closing Price",fontsize=16)
plt.title(f"Closing Price of {symbol}",fontsize=20,fontweight="bold")

plt.xticks(pd.date_range(df["Date"].min(),df["Date"].max()),rotation=60)
plt.show()
