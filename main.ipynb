# %%
from data import download_historical_data, data_summary,handle_missing_values,plot_cumulative_returns
from datetime import date

# %%
symbol="BTC-USD"
start_date="2020-01-01"
end_date = date.today().strftime('%Y-%m-%d')
timeframe="1d"

# %%
df=download_historical_data(symbol,start_date,end_date,timeframe)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data_summary(df)
# Out:
# Data Size: 1678 rows, 6 columns
#                         Open          High           Low         Close  \
# Mean            32900.435691  33628.275755  32121.479040  32928.390197
# Median          29736.416992  30239.732422  29252.701172  29768.647461
# Std             17904.925065  18316.473381  17430.244109  17901.953084
# Missing_values      0.000000      0.000000      0.000000      0.000000
#
#                    Adj Close        Volume
# Mean            32928.390197  3.202380e+10
# Median          29768.647461  2.900987e+10
# Std             17901.953084  1.820077e+10
# Missing_values      0.000000  0.000000e+00

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# 2020-01-05   7410.451660   7544.497070   7400.535645   7411.317383
# ...                  ...           ...           ...           ...
# 2024-07-31  66201.273438  66810.210938  64532.046875  64619.250000
# 2024-08-01  64625.839844  65593.242188  62248.941406  65357.500000
# 2024-08-02  65353.500000  65523.222656  61184.894531  61415.066406
# 2024-08-03  61414.808594  62148.371094  59836.527344  60680.093750
# 2024-08-04  60676.093750  61062.988281  57210.804688  58116.976562
#
#                Adj Close       Volume
# Date
# 2020-01-01   7200.174316  18565664997
# 2020-01-02   6985.470215  20802083465
# ...

# %%
plot_cumulative_returns(df,symbol)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
from trading import strategy_build,execute_trade,plot_signals

# %%
new_df = execute_trade(df)

# %%
plot_signals(df)

# %%
from post_trade_analysis import calculate_returns, calculate_cumulative_returns, calculate_hit_ratio, calculate_max_drawdown, calculate_sharpe_ratio, calculate_sortino_ratio, generate_monthly_returns_heatmap

# %%
returns = calculate_returns(df)
cum_returns = calculate_cumulative_returns(df)

# %%
calculate_hit_ratio(returns)
calculate_sharpe_ratio(returns)
calculate_sortino_ratio(returns)
calculate_max_drawdown(cum_returns)
# Out:
# Hit Ratio is: 0.27906976744186046
# Sharpe Ratio is: 0.21172377319962074
# Sortino Ratio is: 4.596899086080654
# Max Drowdown is: -53.56254256592272 %

# %%
generate_monthly_returns_heatmap(df)
